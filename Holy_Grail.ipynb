# %%
# ─── Block 1: SETUP + TOP-100 USDT-M FUTURES (last 21 days) ─────────────────
from datetime import datetime, timezone, timedelta
import ccxt, pandas as pd, time
from bisect import bisect_right

# 0) FIXED WINDOW: days ago → now
spans = 9
now_utc  = datetime.now(timezone.utc)
start    = now_utc - timedelta(days=spans)
end      = now_utc

print(f"→ Window: {start.isoformat()} → {end.isoformat()}")

# to ms, bump exact-midnight end forward by 1 ms
start_ms = int(start.timestamp() * 1000)
end_ms   = int(  end.timestamp() * 1000)
if end_ms % 86_400_000 == 0:
    end_ms += 86_400_000 - 1

# 1) CCXT FUTURES CLIENT
binance = ccxt.binance({
    'options':        {'defaultType': 'future'},
    'enableRateLimit': True,
})

# 2) GET 24 h STATS FROM USD-MARGined FUTURES
raw24 = binance.fapiPublicGetTicker24hr()    # GET /fapi/v1/ticker/24hr
# filter symbols ending in "USDT"
usdt  = [t for t in raw24 if t['symbol'].endswith('USDT')]
# pick topn by quoteVolume
n=100
topn = sorted(
    usdt,
    key=lambda x: float(x['quoteVolume']),
    reverse=True
)[:n]
# normalize to ccxt unified format "BTC/USDT"
symbols = [ t['symbol'][:-4] + '/USDT' for t in topn ]

print("Top" + str(len(symbols)) + " USDT-M futures by 24 h volume:")
print(symbols)
print()
# Out:
# → Window: 2025-05-31T11:19:16.261457+00:00 → 2025-06-09T11:19:16.261457+00:00
# Top200 USDT-M futures by 24 h volume:
# ['BTC/USDT', 'ETH/USDT', 'ALPACA/USDT', 'SOL/USDT', 'XRP/USDT', '1000PEPE/USDT', 'DOGE/USDT', 'ANIME/USDT', 'SUI/USDT', 'BNX/USDT', 'FARTCOIN/USDT', 'RVN/USDT', 'LA/USDT', 'ADA/USDT', 'WIF/USDT', 'HUMA/USDT', 'MASK/USDT', 'AVAX/USDT', 'UMA/USDT', 'ENA/USDT', 'LPT/USDT', 'AAVE/USDT', 'HMSTR/USDT', 'TRUMP/USDT', 'BNB/USDT', 'TRB/USDT', 'LINK/USDT', 'HYPE/USDT', 'VIRTUAL/USDT', 'SPX/USDT', 'MOODENG/USDT', 'DEXE/USDT', 'SOPH/USDT', 'WLD/USDT', 'UNI/USDT', 'ICP/USDT', 'BCH/USDT', 'VIDT/USDT', 'KAIA/USDT', 'BID/USDT', 'AGIX/USDT', 'INJ/USDT', 'PNUT/USDT', 'WCT/USDT', 'NXPC/USDT', 'LTC/USDT', 'NEIRO/USDT', 'OP/USDT', 'TAO/USDT', 'DOT/USDT', 'TRX/USDT', 'FIL/USDT', 'LINA/USDT', 'KAITO/USDT', 'SHELL/USDT', 'FTM/USDT', 'NEAR/USDT', 'ETHFI/USDT', 'POPCAT/USDT', 'FET/USDT', 'TIA/USDT', 'CRV/USDT', 'WAVES/USDT', '1000SHIB/USDT', 'VVV/USDT', 'AMB/USDT', 'COOKIE/USDT', 'OCEAN/USDT', 'XLM/USDT', 'GPS/USDT', 'CHESS/USDT', 'AIXBT/USDT', '1000BONK/USDT', 'GUN/USDT', 'STRAX/USDT', 'B/USDT', 'ICX/USDT', 'EIGEN/USDT', 'REN/USDT', 'ARB/USDT', 'ONDO/USDT', 'UNFI/USDT', '1000000BOB/USDT', 'HBAR/USDT', 'APT/USDT', 'LDO/USDT', 'AI16Z/USDT', 'ORDI/USDT', 'IOST/USDT', 'TON/USDT', 'SYRUP/USDT', 'DGB/USDT', 'JUP/USDT', 'TUT/USDT', 'TROY/USDT', 'GRASS/USDT', 'MKR/USDT', 'APE/USDT', 'PEOPLE/USDT', 'ETC/USDT', 'CETUS/USDT', 'GALA/USDT', 'PENGU/USDT', 'INIT/USDT', 'COMP/USDT', 'ZEREBRO/USDT', 'SNT/USDT', 'BOME/USDT', 'PROMPT/USDT', 'DYDX/USDT', 'MUBARAK/USDT', 'OM/USDT', 'AVAAI/USDT', 'RAYSOL/USDT', 'BRETT/USDT', 'B2/USDT', 'SKATE/USDT', 'MOVE/USDT', 'THE/USDT', 'CHILLGUY/USDT', 'PAXG/USDT', 'SOON/USDT', 'GOAT/USDT', 'BLZ/USDT', '1000FLOKI/USDT', 'PENDLE/USDT', 'TURBO/USDT', 'RENDER/USDT', 'BROCCOLIF3B/USDT', 'ATOM/USDT', 'BDXN/USDT', 'SWARMS/USDT', 'BMT/USDT', 'GRIFFAIN/USDT', 'COMBO/USDT', 'S/USDT', 'ENS/USDT', 'SAND/USDT', 'NULS/USDT', 'VANA/USDT', 'SEI/USDT', 'PARTI/USDT', 'FLM/USDT', 'STX/USDT', 'ALGO/USDT', 'ZRO/USDT', 'BERA/USDT', 'KEY/USDT', 'ARKM/USDT', '1000SATS/USDT', 'CAKE/USDT', 'LAYER/USDT', 'JELLYJELLY/USDT', 'LOOM/USDT', 'ARC/USDT', 'XMR/USDT', 'HAEDAL/USDT', 'RUNE/USDT', 'PYTH/USDT', 'BANANAS31/USDT', 'AERGO/USDT', 'AXS/USDT', 'SSV/USDT', 'DOGS/USDT', 'MDT/USDT', 'NEIROETH/USDT', 'ZEN/USDT', 'SXT/USDT', 'TST/USDT', 'POL/USDT', 'ME/USDT', 'QNT/USDT', 'DEGO/USDT', 'AR/USDT', 'SIGN/USDT', 'PHA/USDT', 'NEO/USDT', 'A/USDT', 'KLAY/USDT', 'OMG/USDT', 'MEW/USDT', 'VET/USDT', 'PORT3/USDT', 'CFX/USDT', 'SAGA/USDT', 'JTO/USDT', 'BOND/USDT', 'FUN/USDT', 'LQTY/USDT', 'DOOD/USDT', 'BABY/USDT', 'STRK/USDT', 'USUAL/USDT', 'REEF/USDT', 'THETA/USDT', 'NOT/USDT', 'IO/USDT', 'SUSHI/USDT', 'KAS/USDT', 'XEM/USDT']

# %%
# ─── Block 2: fetch_ohlcv_until() + scan_symbol() ───────────────────────────
import numpy as np
from ta.trend      import MACD, ADXIndicator, EMAIndicator
from ta.volatility import AverageTrueRange
from ta.momentum   import RSIIndicator
import ta  # for MFI

def fetch_ohlcv_until(symbol, timeframe, start_ms, end_ms, limit=1500):
    all_bars, cursor = [], start_ms
    delay = binance.rateLimit/1000
    while True:
        batch = binance.fetch_ohlcv(symbol, timeframe, since=cursor, limit=limit)
        if not batch: break
        last = batch[-1][0]
        all_bars += batch
        print(f"  • fetched {len(batch)} bars → {pd.to_datetime(last,unit='ms')} UTC")
        if last >= end_ms:
            all_bars = [b for b in all_bars if b[0] <= end_ms]
            print("    ▶ reach end_ms, stopping.")
            break
        cursor = last+1
        time.sleep(delay)
        if len(batch)<limit: break

    df = pd.DataFrame(all_bars, columns=['ts','open','high','low','close','volume'])
    df['timestamp'] = pd.to_datetime(df['ts'],unit='ms')
    df.set_index('timestamp',inplace=True)
    df.drop('ts',axis=1,inplace=True)
    df = df[(df.index>=pd.to_datetime(start_ms,unit='ms'))
          & (df.index<=pd.to_datetime(end_ms,  unit='ms'))]
    df.index = df.index.tz_localize('UTC').tz_convert('Asia/Bangkok')
    return df

def safe_round(value, ndigits=0):
    if isinstance(value, (int, float)):
        return round(value, ndigits)
    return value  # Leave it unchanged if not a number

def scan_symbol(symbol, start_ms, end_ms):
    print(f"▶ scanning {symbol}")
    # 1) fetch 15m + warmup 4h
    df15 = fetch_ohlcv_until(symbol, '15m', start_ms, end_ms)
    MS4H = 4*60*60*1000
    warm = start_ms - (14*10 + 5)*MS4H
    raw4 = fetch_ohlcv_until(symbol, '4h', warm, end_ms)
    # slice raw4 → exact window
    sdt = pd.to_datetime(start_ms,unit='ms',utc=True).tz_convert('Asia/Bangkok')
    edt = pd.to_datetime(end_ms,  unit='ms',utc=True).tz_convert('Asia/Bangkok')
    df4  = raw4.loc[sdt:edt]

    # 2) merge 4h → 15m
    # ─── 4h → 15m ATR & ADX (guard against too-short history + catch errors) ──────────────────
    WINDOW = 14

    if len(raw4) < WINDOW + 1:
        # Not enough 4h bars to compute a 14-period indicator
        atr4 = pd.Series(0.0, index=df15.index)
        adx4 = pd.Series(0.0, index=df15.index)
    else:
        # ATR(14)
        atr4 = AverageTrueRange(
            high= raw4['high'],
            low=  raw4['low'],
            close=raw4['close'],
            window=WINDOW
        ).average_true_range()

        # ADX(14) with exception handling
        try:
            adx_series = ADXIndicator(
                high= raw4['high'],
                low=  raw4['low'],
                close=raw4['close'],
                window=WINDOW,
                fillna=False
            ).adx()
            adx4 = adx_series.fillna(0)
        except Exception as e:
            print(f"    ⚠️ ADX calculation failed for {symbol}: {e}. Zero-filling it.")
            adx4 = pd.Series(0.0, index=raw4.index)

    # forward-fill onto the 15m frame
    df15['ATR_4h'] = atr4.reindex(df15.index, method='ffill')
    df15['ADX_4h'] = adx4.reindex(df15.index, method='ffill')

    # 3) 15m indicators
    macd = MACD(df15['close'])
    df15['MACD_line']   = macd.macd()
    df15['MACD_signal'] = macd.macd_signal()
    df15['MACD_hist']   = macd.macd_diff()
    df15['MFI']   = ta.volume.money_flow_index(df15['high'],df15['low'],df15['close'],df15['volume'],14)
    df15['EMA50'] = EMAIndicator(df15['close'],50).ema_indicator()
    df15['EMA100']= EMAIndicator(df15['close'],100).ema_indicator()
    df15['RSI']   = RSIIndicator(df15['close'],14).rsi()
    df15['ATR']   = AverageTrueRange(df15['high'],df15['low'],df15['close'],14).average_true_range()
    df15['ATR30']= df15['ATR'].rolling(30).mean()
    df15['ADX']  = ADXIndicator(df15['high'],df15['low'],df15['close'],14).adx()
    df15.dropna(inplace=True)

    # 4) pivots
    pw = 10
    df15['is_pivot_high'] = df15['high'].rolling(2*pw+1,center=True)\
                                  .apply(lambda x: np.argmax(x)==pw,raw=True)
    df15['is_pivot_low']  = df15['low'].rolling (2*pw+1,center=True)\
                                  .apply(lambda x: np.argmin(x)==pw,raw=True)
    highs = df15.loc[df15['is_pivot_high']==1,'high']
    lows  = df15.loc[df15['is_pivot_low']==1, 'low']
    HT, HV = highs.index.tolist(), highs.values.tolist()
    LT, LV = lows.index.tolist(),  lows.values.tolist()

    # 5) backtest exactly as before
    results, active = [], False
    lev, cap, base_rr, rr_min, th = 10, 25, 1.5, 0.15, 25
    risk_th = 0.75
    fee = 0.0005
    for i in range(1,len(df15)):
        r, p = df15.iloc[i], df15.iloc[i-1]
        now  = r.name

        if not active:
            # trend filter
            if r['ADX_4h']<th: continue
            else:
                # LONG
                if ( r['high']>=r['EMA50'] and r['EMA50']>r['EMA100']
                and p['MFI']<=45         and r['MFI']>=45
                and r['MACD_hist']>0):
                    entry, entry_t, side = r['close'], now, 'long'
                    active=True
                    risk = r['ATR_4h']*risk_th
                    stop = entry-risk
                    idx  = bisect_right(HT,entry_t)
                    cand = HV[idx] if idx<len(HV) else entry+base_rr*risk
                    tp   = cand if cand>entry else entry+base_rr*risk
                    rr   = (tp-entry)/risk
                
                    # ❌ only go active if R:R > RR_MIN
                    if rr <= rr_min:
                        continue

                    active = True

                # SHORT
                elif ( r['low']<=r['EMA50'] and r['EMA50']<r['EMA100']
                    and p['MFI']>=55 and r['MFI']<=55
                    and r['MACD_hist']<0):
                    entry, entry_t, side = r['close'], now, 'short'
                    active=True
                    risk = r['ATR_4h']*risk_th
                    stop = entry+risk
                    idx  = bisect_right(LT,entry_t)
                    cand = LV[idx] if idx<len(LV) else entry-risk*base_rr
                    tp   = cand if cand<entry else entry-risk*base_rr
                    rr   = abs((tp-entry)/risk)

                    # ❌ only go active if R:R > 1
                    if rr <= rr_min:
                        continue
                    
                    active = True

                else:
                    continue

        else:
            lo, hi = r['low'], r['high']
            if side=='long':
                if lo<=stop: result,exit_price='loss',stop
                elif hi>=tp:   result,exit_price='win', tp
                else:          continue
            else:
                if hi>=stop:   result,exit_price='loss',stop
                elif lo<=tp:   result,exit_price='win', tp
                else:          continue

            # pnl + fees
            pnl_pct = ((exit_price-entry)/entry)*(1 if side=='long' else -1)*lev*100
            pnl_usd = cap*pnl_pct/100
            not_usd = cap*lev
            qty     = safe_round(not_usd/entry,4)
            fees    = qty*(entry+exit_price)*0.5*fee
            net     = pnl_usd - fees

            results.append({
                'symbol':      symbol,
                'side':        side,
                'entry_time':  entry_t,
                'exit_time':   now,
                'entry_price': entry,
                'stop_loss':   stop,
                'take_profit': tp,
                # 'exit_price':  exit_price,
                # 'volume_$':    safe_round(not_usd,2),
                # 'fees_$':      safe_round(fees,4),
                # 'pnl_%':       safe_round(pnl_pct,2),
                # 'pnl_$':       safe_round(pnl_usd,2),
                # 'net_pnl_$':   safe_round(net,2),
                'R:R':         safe_round(rr,2)
            })
            active=False
        
        if active: 
            pnl_pct = None
            pnl_usd = None
            not_usd = cap*lev
            qty     = safe_round(not_usd/entry,4)
            fees    = None
            net     = None
        
            results.append({
                'symbol':      symbol,
                'side':        side,
                'entry_time':  entry_t,
                'exit_time':   None,
                'entry_price': entry,
                'stop_loss':   stop,
                'take_profit': tp,
                # 'exit_price':  None,
                # 'volume_$':    safe_round(not_usd,2),
                # 'fees_$':      safe_round(fees,4),
                # 'pnl_%':       safe_round(pnl_pct,2),
                # 'pnl_$':       safe_round(pnl_usd,2),
                # 'net_pnl_$':   safe_round(net,2),
                'R:R':         safe_round(rr,2)
            })
    
        
    # Build results DataFrame
    result_df = pd.DataFrame(results)

    # Keep only the final trade (or return an empty DataFrame if there were none)
    result_df = result_df.tail(1).reset_index(drop=True)

    return result_df

# %%
# # ─── Block 3: scan each symbol and collect only still‐open trades ─────────────────
# open_trades = []
# i = 0 
# for sym in symbols:
#     i = i+1
#     print(f"▶ {i} scanning {sym}")
#     # run your backtest function, which must return a DataFrame `df_trades`
#     # with at least these columns: entry_time, exit_time, …, net_pnl_$
#     df_trades = scan_symbol(sym, start_ms, end_ms)

#     # 1) skip if backtest gave you nothing at all
#     if df_trades is None or df_trades.empty:
#         continue

#     # 2) if exit_time never made it into the DataFrame, skip
#     if 'exit_time' not in df_trades.columns:
#         print(f"   ⚠️  '{sym}' returned no exit_time column, skipping")
#         continue

#     # 3) find rows where exit_time is still NaT → these are your "active" orders
#     still_open = df_trades[df_trades['exit_time'].isna()].copy()
#     if still_open.empty:
#         continue

#     # 4) attach the symbol so we know which market
#     still_open['symbol'] = sym
#     open_trades.append(still_open)

# # ─── at the end: display everything you found
# if open_trades:
#     print("\n📋 Active orders:")
#     display(pd.concat(open_trades, ignore_index=True))
# else:
#     print("\n✅ No active trades at the moment.")

# %%
# # ─── Block 3: scan each symbol in parallel and collect only still-open trades ───────────
# import pandas as pd
# from concurrent.futures import ThreadPoolExecutor, as_completed

# def _process_symbol(sym):
#     """Fetch & backtest one symbol; return only the still-open trade (or None)."""
#     try:
#         df_trades = scan_symbol(sym, start_ms, end_ms)
#         # nothing returned or no exit_time column?
#         if df_trades is None or df_trades.empty or 'exit_time' not in df_trades:
#             return None
#         # select rows where exit_time is NaT → active/open trades
#         still_open = df_trades[df_trades['exit_time'].isna()].copy()
#         if still_open.empty:
#             return None
#         still_open['symbol'] = sym
#         return still_open
#     except Exception as e:
#         print(f"⚠️ Error processing {sym}: {e}")
#         return None

# open_trades = []
# max_workers = 10  # tune this up/down for rate-limit comfort
# with ThreadPoolExecutor(max_workers=max_workers) as executor:
#     # submit all symbols at once
#     futures = {executor.submit(_process_symbol, sym): sym for sym in symbols}
#     for fut in as_completed(futures):
#         res = fut.result()
#         if res is not None:
#             open_trades.append(res)

# # final display
# if open_trades:
#     print("\n📋 Active orders:")
#     display(pd.concat(open_trades, ignore_index=True))
# else:
#     print("\n✅ No active trades at the moment.")
# Out:
# ▶ scanning BTC/USDT▶ scanning ETH/USDT
#
# ▶ scanning ALPACA/USDT
# ▶ scanning SOL/USDT
# ▶ scanning XRP/USDT
# ▶ scanning 1000PEPE/USDT
# ▶ scanning DOGE/USDT
# ▶ scanning ANIME/USDT
# ▶ scanning SUI/USDT
# ▶ scanning BNX/USDT
# ▶ scanning FARTCOIN/USDT
# ▶ scanning RVN/USDT
# ▶ scanning LA/USDT
# ▶ scanning ADA/USDT
# ▶ scanning WIF/USDT
# ▶ scanning HUMA/USDT
# ▶ scanning MASK/USDT
# ▶ scanning AVAX/USDT
# ▶ scanning UMA/USDT
# ▶ scanning ENA/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 394 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 25 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#     ⚠️ ADX calculation failed for LA/USDT: index 14 is out of bounds for axis 0 with size 12. Zero-filling it.
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning LPT/USDT
# ▶ scanning AAVE/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning HMSTR/USDT
# ▶ scanning TRUMP/USDT
# ▶ scanning BNB/USDT
# ▶ scanning TRB/USDT
# ▶ scanning LINK/USDT
# ▶ scanning HYPE/USDT
# ▶ scanning VIRTUAL/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 84 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning SPX/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning MOODENG/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning DEXE/USDT
# ▶ scanning SOPH/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning WLD/USDT
#   • fetched 61 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning UNI/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning ICP/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning BCH/USDT
# ▶ scanning VIDT/USDT
# ▶ scanning KAIA/USDT
#   • fetched 72 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning BID/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning AGIX/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning INJ/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning PNUT/USDT
# ▶ scanning WCT/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning NXPC/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning LTC/USDT
# ▶ scanning NEIRO/USDT
# ▶ scanning OP/USDT
# ▶ scanning TAO/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning DOT/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning TRX/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning FIL/USDT
# ▶ scanning LINA/USDT
# ▶ scanning KAITO/USDT
# ▶ scanning SHELL/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning FTM/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 152 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning NEAR/USDT
# ▶ scanning ETHFI/USDT
# ▶ scanning POPCAT/USDT
# ▶ scanning FET/USDT
# ▶ scanning TIA/USDT
# ▶ scanning CRV/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning WAVES/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning 1000SHIB/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning VVV/USDT
# ▶ scanning AMB/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning COOKIE/USDT  • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning OCEAN/USDT
# ▶ scanning XLM/USDT
# ▶ scanning GPS/USDT
# ▶ scanning CHESS/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning AIXBT/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning 1000BONK/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning GUN/USDT
# ▶ scanning STRAX/USDT
# ▶ scanning B/USDT
# ▶ scanning ICX/USDT
# ▶ scanning EIGEN/USDT
# ▶ scanning REN/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning ARB/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning ONDO/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning UNFI/USDT
# ▶ scanning 1000000BOB/USDT
# ▶ scanning HBAR/USDT
# ▶ scanning APT/USDT
# ▶ scanning LDO/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning AI16Z/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning ORDI/USDT
# ▶ scanning IOST/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning TON/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 396 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning SYRUP/USDT
# ▶ scanning DGB/USDT
# ▶ scanning JUP/USDT
# ▶ scanning TUT/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 25 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning TROY/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning GRASS/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#     ⚠️ ADX calculation failed for 1000000BOB/USDT: index 14 is out of bounds for axis 0 with size 12. Zero-filling it.
#   • fetched 107 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning MKR/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning APE/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning PEOPLE/USDT
# ▶ scanning ETC/USDT
# ▶ scanning CETUS/USDT
# ▶ scanning GALA/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning PENGU/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning INIT/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning COMP/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning ZEREBRO/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning SNT/USDT
# ▶ scanning BOME/USDT
# ▶ scanning PROMPT/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning DYDX/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning MUBARAK/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning OM/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning AVAAI/USDT
# ▶ scanning RAYSOL/USDT
# ▶ scanning BRETT/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning B2/USDT
# ▶ scanning SKATE/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ▶ scanning MOVE/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning THE/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 4 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning CHILLGUY/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning PAXG/USDT
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning SOON/USDT
# ▶ scanning GOAT/USDT
# ▶ scanning BLZ/USDT
# ▶ scanning 1000FLOKI/USDT
# ⚠️ Error processing THE/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning PENDLE/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
# ⚠️ Error processing PROMPT/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning TURBO/USDT
# ⚠️ Error processing AVAAI/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning RENDER/USDT
# ▶ scanning BROCCOLIF3B/USDT
# ⚠️ Error processing RAYSOL/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning ATOM/USDT
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
#   • fetched 199 bars → 2025-06-09 08:00:00 UTC
#   • fetched 864 bars → 2025-06-09 11:15:00 UTC
# ▶ scanning BDXN/USDT
# ▶ scanning SWARMS/USDT
# ⚠️ Error processing SKATE/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning BMT/USDT
# ▶ scanning GRIFFAIN/USDT
# ▶ scanning COMBO/USDT
# ▶ scanning S/USDT
# ⚠️ Error processing PAXG/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning ENS/USDT
# ⚠️ Error processing RENDER/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning SAND/USDT
# ⚠️ Error processing ATOM/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning NULS/USDT
# ⚠️ Error processing CHILLGUY/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning VANA/USDT
# ▶ scanning SEI/USDT
# ⚠️ Error processing 1000FLOKI/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning PARTI/USDT
# ⚠️ Error processing BDXN/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning FLM/USDT
# ⚠️ Error processing SOON/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning STX/USDT
# ⚠️ Error processing BROCCOLIF3B/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning ALGO/USDT
# ⚠️ Error processing GOAT/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning ZRO/USDT
# ⚠️ Error processing TURBO/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning BERA/USDT
# ▶ scanning KEY/USDT
# ▶ scanning ARKM/USDT
# ⚠️ Error processing SWARMS/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning 1000SATS/USDT
# ⚠️ Error processing BMT/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning CAKE/USDT
# ⚠️ Error processing BLZ/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning LAYER/USDT
# ⚠️ Error processing PENDLE/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning JELLYJELLY/USDT
# ⚠️ Error processing S/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning LOOM/USDT
# ⚠️ Error processing NULS/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning ARC/USDT
# ⚠️ Error processing BERA/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning XMR/USDT
# ⚠️ Error processing VANA/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning HAEDAL/USDT
# ⚠️ Error processing GRIFFAIN/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning RUNE/USDT
# ⚠️ Error processing FLM/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning PYTH/USDT
# ⚠️ Error processing ALGO/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning BANANAS31/USDT
# ⚠️ Error processing SAND/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning AERGO/USDT
# ⚠️ Error processing STX/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning AXS/USDT
# ⚠️ Error processing AXS/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}⚠️ Error processing BANANAS31/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning SSV/USDT
# ⚠️ Error processing PYTH/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning DOGS/USDT
# ⚠️ Error processing CAKE/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning MDT/USDT
# ⚠️ Error processing XMR/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning NEIROETH/USDT
# ⚠️ Error processing HAEDAL/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning ZEN/USDT
# ⚠️ Error processing LOOM/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning SXT/USDT
# ⚠️ Error processing 1000SATS/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning TST/USDT
#
# ▶ scanning POL/USDT
# ⚠️ Error processing LAYER/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning ME/USDT
# ⚠️ Error processing ARC/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning QNT/USDT
# ⚠️ Error processing ZRO/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}⚠️ Error processing KEY/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning DEGO/USDT
#
# ▶ scanning AR/USDT
# ⚠️ Error processing PARTI/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning SIGN/USDT
# ⚠️ Error processing SEI/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning PHA/USDT
# ⚠️ Error processing POL/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468226866. Please use the websocket for live updates to avoid bans."}
# ▶ scanning NEO/USDT
# ⚠️ Error processing TST/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ▶ scanning A/USDT
# ⚠️ Error processing PHA/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ▶ scanning KLAY/USDT
# ⚠️ Error processing QNT/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning OMG/USDT
# ⚠️ Error processing DEGO/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ▶ scanning MEW/USDT
# ⚠️ Error processing MDT/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning VET/USDT
# ⚠️ Error processing ZEN/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468466868. Please use the websocket for live updates to avoid bans."}
# ▶ scanning PORT3/USDT
# ⚠️ Error processing ME/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468226866. Please use the websocket for live updates to avoid bans."}
# ▶ scanning CFX/USDT
# ⚠️ Error processing NEIROETH/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ▶ scanning SAGA/USDT
# ⚠️ Error processing DOGS/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468346867. Please use the websocket for live updates to avoid bans."}
# ▶ scanning JTO/USDT
# ⚠️ Error processing COMBO/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning BOND/USDT
# ⚠️ Error processing AERGO/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468586929. Please use the websocket for live updates to avoid bans."}
# ▶ scanning FUN/USDT
# ⚠️ Error processing ENS/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning LQTY/USDT
# ⚠️ Error processing RUNE/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468466868. Please use the websocket for live updates to avoid bans."}
# ▶ scanning DOOD/USDT
# ⚠️ Error processing ARKM/USDT: binance 429 Too Many Requests {"code":-1003,"msg":"Too many requests; current limit of IP(171.253.176.183) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ▶ scanning BABY/USDT
# ⚠️ Error processing JELLYJELLY/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468706929. Please use the websocket for live updates to avoid bans."}
# ▶ scanning STRK/USDT
# ⚠️ Error processing KLAY/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468466868. Please use the websocket for live updates to avoid bans."}
# ▶ scanning USUAL/USDT
# ⚠️ Error processing NEO/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468706929. Please use the websocket for live updates to avoid bans."}
# ▶ scanning REEF/USDT
# ⚠️ Error processing MEW/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ▶ scanning THETA/USDT
# ⚠️ Error processing PORT3/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468827348. Please use the websocket for live updates to avoid bans."}
# ▶ scanning NOT/USDT
# ⚠️ Error processing BOND/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468346867. Please use the websocket for live updates to avoid bans."}
# ▶ scanning IO/USDT
# ⚠️ Error processing VET/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468947349. Please use the websocket for live updates to avoid bans."}
# ▶ scanning SUSHI/USDT
# ⚠️ Error processing DOOD/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ▶ scanning KAS/USDT
# ⚠️ Error processing CFX/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ▶ scanning XEM/USDT
# ⚠️ Error processing OMG/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468466868. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing SAGA/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468827348. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing IO/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468947349. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing SUSHI/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing NOT/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468226866. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing KAS/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468827348. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing THETA/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468346867. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing XEM/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing REEF/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468947349. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing USUAL/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468346867. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing SSV/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468226866. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing SXT/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing AR/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468226866. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing SIGN/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing STRK/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing FUN/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468706929. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing BABY/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468226866. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing LQTY/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468226866. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing A/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468106865. Please use the websocket for live updates to avoid bans."}
# ⚠️ Error processing JTO/USDT: binance 418 I'm a teapot {"code":-1003,"msg":"Way too many requests; IP(171.253.176.183) banned until 1749468827348. Please use the websocket for live updates to avoid bans."}
#
# 📋 Active orders:
#        symbol   side                entry_time exit_time  entry_price  \
# 0   HUMA/USDT  short 2025-06-09 14:45:00+07:00       NaT     0.049263
# 1    GPS/USDT   long 2025-06-09 11:00:00+07:00       NaT     0.025580
# 2  CHESS/USDT   long 2025-06-09 17:30:00+07:00       NaT     0.076860
# 3    TUT/USDT   long 2025-06-09 17:00:00+07:00       NaT     0.031330
#
#    stop_loss  take_profit  R:R
# 0   0.051970     0.045203  1.5
# 1   0.024860     0.026660  1.5
# 2   0.074652     0.080172  1.5
# 3   0.030738     0.032218  1.5

# %%
# ─── Block 3: scan each symbol in parallel and collect only still-open trades ───────────
import time
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

# how long to sleep to respect binance.rateLimit
rate_limit_sec = binance.rateLimit / 1000  

def _process_symbol(sym):
    """
    Sleep once to throttle against rateLimit,
    then fetch/backtest `sym` and return only still-open trades (or None).
    """
    # throttle this thread’s first request
    time.sleep(rate_limit_sec)
    try:
        df_trades = scan_symbol(sym, start_ms, end_ms)
        # nothing or no exit_time column?
        if df_trades is None or df_trades.empty or 'exit_time' not in df_trades:
            return None

        # select only the rows where exit_time is NaT → still open
        still_open = df_trades[df_trades['exit_time'].isna()].copy()
        if still_open.empty:
            return None

        still_open['symbol'] = sym
        return still_open

    except Exception as e:
        print(f"⚠️ Error processing {sym}: {e}")
        return None

open_trades = []
max_workers = 5  # feel free to tune down if you still hit bans

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    # kick off one future per symbol
    futures = {executor.submit(_process_symbol, sym): sym for sym in symbols}

    for fut in as_completed(futures):
        res = fut.result()
        if res is not None:
            open_trades.append(res)

# ─── display your still-open trades ───────────────────────────────────────────────
if open_trades:
    print("\n📋 Active orders:")
    display(pd.concat(open_trades, ignore_index=True))
else:
    print("\n✅ No active trades at the moment.")
